# %% [markdown]
# # Ford_car_sell_analysis_1

# %% [markdown]
# ###### Data source link: https://github.com/SKawsar/Data_Visualization_with_Python
# Original data source: https://www.kaggle.com/aishwaryamuthukumar/cars-dataset-audi-bmw-ford-hyundai-skoda-vw

# %% [markdown]
# ###### Objective
#
# EDA using groupby/pivot_table and barplot (total 9 barplots), based on model, transmission, and fuelType.
#
# Finding the top 5 selling car models in the dataset.
#
# Finding average selling price of the top 5 selling car models.
#
# Finding the total sale of the top 5 selling car models.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")
sns.set_style("darkgrid")

# %%
 df =pd.read_csv("ford.csv")
ford = pd.read_csv("ford.csv")
display(ford.head())
# Out:
#      model  year  price transmission  mileage fuelType   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  48.7         1.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17964 entries, 0 to 17963
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17964 non-null  object
#  1   year          17964 non-null  int64
#  2   price         17964 non-null  int64
#  3   transmission  17964 non-null  object
#  4   mileage       17964 non-null  int64
#  5   fuelType      17964 non-null  object
#  6   mpg           17964 non-null  float64
#  7   engineSize    17964 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# ## The top 5 selling car models, Average selling price & Toatl selling price of the top 5 selling car in the dataset.

# %%
df_agg = df.groupby('model')['price'].agg(['count', 'mean', 'sum'])

display(df_agg)
# Out:
#                         count          mean       sum
# model
#  B-MAX                    355   8287.526761   2942072
#  C-MAX                    543   9914.567219   5383610
#  EcoSport                1143  12499.268591  14286664
#  Edge                     208  22810.500000   4744584
#  Escort                     1   3000.000000      3000
#  Fiesta                  6556  10196.862569  66850631
#  Focus                   4588  13185.882956  60496831
#  Fusion                    16   2555.812500     40893
#  Galaxy                   228  17841.872807   4067947
#  Grand C-MAX              247  10881.574899   2687749
#  Grand Tourneo Connect     59  14874.915254    877620
#  KA                       199   5186.125628   1032039
#  Ka+                      531   8707.856874   4623872
#  Kuga                    2225  15823.472360  35207226
#  Mondeo                   526  12305.709125   6472803
#  Mustang                   57  34631.263158   1973982
# ...

# %%
df_agg = df_agg.sort_values(by='count', ascending=False)
df_agg['sum'] = df_agg['sum']/1000000
df_agg = df_agg.round(2)

display(df_agg.head(5))
# Out:
#            count      mean    sum
# model
#  Fiesta     6556  10196.86  66.85
#  Focus      4588  13185.88  60.50
#  Kuga       2225  15823.47  35.21
#  EcoSport   1143  12499.27  14.29
#  C-MAX       543   9914.57   5.38

# %% [markdown]
# ###### The top 5 selling car models in the dataset - Fiesta	, Focus, Kuga, EcoSport, C-MAX

# %% [markdown]
# ###### Average selling price (USD) of the top 5 selling car models
#
# Fiesta	10196.86
#
# Focus	13185.88
#
# Kuga	15823.47
#
# EcoSport	12499.27
#
# C-MAX	9914.57

# %% [markdown]
# ###### Toatl selling price (Millions in USD) of the top 5 selling car
#
# Fiesta 66.85
#
# Focus 60.50
#
# Kuga 35.21
#
# EcoSport 14.29
#
# C-MAX 5.38

# %% [markdown]
# ## EDA using groupby/pivot_table and barplot based on model, transmission, and fuelType

# %%
df_agg['percent_of_cars'] = (df_agg['count']/df_agg['count'].sum())*100
display(df_agg.head())
# Out:
#            count      mean    sum  percent_of_cars
# model
#  Fiesta     6556  10196.86  66.85        36.495213
#  Focus      4588  13185.88  60.50        25.539969
#  Kuga       2225  15823.47  35.21        12.385883
#  EcoSport   1143  12499.27  14.29         6.362725
#  C-MAX       543   9914.57   5.38         3.022712

# %%
print(df['model'].unique())
print(df['transmission'].unique())
print(df['fuelType'].unique())
# Out:
# [' Fiesta' ' Focus' ' Puma' ' Kuga' ' EcoSport' ' C-MAX' ' Mondeo' ' Ka+'
#  ' Tourneo Custom' ' S-MAX' ' B-MAX' ' Edge' ' Tourneo Connect'
#  ' Grand C-MAX' ' KA' ' Galaxy' ' Mustang' ' Grand Tourneo Connect'
#  ' Fusion' ' Ranger' ' Streetka' ' Escort' ' Transit Tourneo']
# ['Automatic' 'Manual' 'Semi-Auto']
# ['Petrol' 'Diesel' 'Hybrid' 'Electric' 'Other']

# %%
model_count = df['model'].value_counts()
display(model_count)
# Out:
#  Fiesta                   6556
#  Focus                    4588
#  Kuga                     2225
#  EcoSport                 1143
#  C-MAX                     543
#  Ka+                       531
#  Mondeo                    526
#  B-MAX                     355
#  S-MAX                     296
#  Grand C-MAX               247
#  Galaxy                    228
#  Edge                      208
#  KA                        199
#  Puma                       80
#  Tourneo Custom             69
#  Grand Tourneo Connect      59
#  Mustang                    57
#  Tourneo Connect            33
#  Fusion                     16
#  Streetka                    2
#  Escort                      1
#  Ranger                      1
#  Transit Tourneo             1
# Name: model, dtype: int64

# %%
df_agg['percent_of_cars'] = (df_agg['count']/df_agg['count'].sum())*100
display(df_agg.head())
# Out:
#            count      mean    sum  percent_of_cars
# model
#  Fiesta     6556  10196.86  66.85        36.495213
#  Focus      4588  13185.88  60.50        25.539969
#  Kuga       2225  15823.47  35.21        12.385883
#  EcoSport   1143  12499.27  14.29         6.362725
#  C-MAX       543   9914.57   5.38         3.022712

# %%
model_count = pd.DataFrame(model_count)
model_count = model_count.reset_index()
model_count = model_count.rename(columns={'index':'model', 'model':'No_of_cars'})
model_count['% of cars'] = np.round(((model_count['No_of_cars']/model_count['No_of_cars'].sum())*100), 2)
display(model_count)
# Out:
#                      model  No_of_cars  % of cars
# 0                   Fiesta        6556      36.50
# 1                    Focus        4588      25.54
# 2                     Kuga        2225      12.39
# 3                 EcoSport        1143       6.36
# 4                    C-MAX         543       3.02
# 5                      Ka+         531       2.96
# 6                   Mondeo         526       2.93
# 7                    B-MAX         355       1.98
# 8                    S-MAX         296       1.65
# 9              Grand C-MAX         247       1.37
# 10                  Galaxy         228       1.27
# 11                    Edge         208       1.16
# 12                      KA         199       1.11
# 13                    Puma          80       0.45
# 14          Tourneo Custom          69       0.38
# 15   Grand Tourneo Connect          59       0.33
# 16                 Mustang          57       0.32
# 17         Tourneo Connect          33       0.18
# ...

# %%
transmission_count = df['transmission'].value_counts()
display(transmission_count)
# Out:
# Manual       15517
# Automatic     1360
# Semi-Auto     1087
# Name: transmission, dtype: int64

# %%
transmission_count = pd.DataFrame(transmission_count)
transmission_count = transmission_count.reset_index()
transmission_count = transmission_count.rename(columns={'index':'transmission', 'transmission':'No_of_cars'})
transmission_count['% of cars'] = np.round(((transmission_count['No_of_cars']/transmission_count['No_of_cars'].sum())*100), 2)
display(transmission_count)
# Out:
#   transmission  No_of_cars  % of cars
# 0       Manual       15517      86.38
# 1    Automatic        1360       7.57
# 2    Semi-Auto        1087       6.05

# %%
fuelType_count = df['fuelType'].value_counts()
display(fuelType_count)
# Out:
# Petrol      12177
# Diesel       5762
# Hybrid         22
# Electric        2
# Other           1
# Name: fuelType, dtype: int64

# %%
fuelType_count = pd.DataFrame(fuelType_count)
fuelType_count = fuelType_count.reset_index()
fuelType_count = fuelType_count.rename(columns={'index':'fuel_type', 'fuelType':'No_of_cars'})
fuelType_count['% of cars'] = np.round(((fuelType_count['No_of_cars']/fuelType_count['No_of_cars'].sum())*100), 2)
display(fuelType_count)
# Out:
#   fuel_type  No_of_cars  % of cars
# 0    Petrol       12177      67.79
# 1    Diesel        5762      32.08
# 2    Hybrid          22       0.12
# 3  Electric           2       0.01
# 4     Other           1       0.01

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,3,1)
sns.barplot(x='% of cars', y='model', data=model_count,color='green')
plt.title("Number of cars for each model")
plt.xlabel("Ford car models")
plt.ylabel("Percent of cars (%)")

plt.subplot(1,3,2)
sns.barplot(x='transmission', y='% of cars', data=transmission_count, color='blue')
plt.title("Number of cars  for each transmission type")
plt.xlabel("Type of transmission")
plt.ylabel("Percent of cars (%)")

plt.subplot(1,3,3)
sns.barplot(x='fuel_type', y='% of cars', data=fuelType_count, color='red')
plt.title("Number of cars  for each fuelType")
plt.xlabel("Type of fuel")
plt.ylabel("Percent of cars (%)")
# Out:
# Text(0, 0.5, 'Percent of cars (%)')
